# %% [markdown]
# # YOLOv8 Training Notebook (Nvidia A100)

# %%
import os 
import random
import cv2

# %%
#%pip install ultralytics

import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 23.3/78.2 GB disk)

# %%
model = YOLO('yolov8n.pt') 
model.train(data='/content/depondfi_2/data.yaml', epochs=50, imgsz=640, batch=128, name="yolov8n_fish", cache=True, device=0)
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
from google.colab import files
files.download("/content/runs/detect/yolov8n_fish2/weights/best.pt")
files.download("/content/runs/detect/yolov8n_fish2/weights/last.pt")
